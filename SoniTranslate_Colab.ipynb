# %% [markdown]
# <a href="https://colab.research.google.com/github/OnlyRyNMC/SoniTranslate/blob/main/SoniTranslate_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SoniTranslate
#
# | Description | Link |
# | ----------- | ---- |
# | 🎉 Repository | [![GitHub Repository](https://img.shields.io/badge/GitHub-Repository-black?style=flat-square&logo=github)](https://github.com/R3gm/SoniTranslate/) |
# | 🚀 Online Demo in HF | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/r3gm/SoniTranslate_translate_audio_of_a_video_content) |

# %%
# @title Install requirements for SoniTranslate
# %cd /content
# !git clone https://github.com/r3gm/SoniTranslate.git
# %cd SoniTranslate

# !pip uninstall chex pandas-stubs ibis-framework albumentations albucore jax -y -q
# !pip install uv==0.8.13 -q
# !uv venv --python 3.10 --clear -q
# !curl -sS https://bootstrap.pypa.io/get-pip.py -o get-pip.py
# !uv run python get-pip.py pip==23.1.2 -q
# In Colab, this is how you use uv, got it?
# !uv run python -m pip install -q pip==23.1.2 Setuptools==80.6.0
# !apt install git-lfs -q
# !git lfs install

# !uv run python -m pip install -q torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1 --index-url https://download.pytorch.org/whl/cu124
# !sed -i 's|git+https://github.com/R3gm/whisperX.git@cuda_11_8|git+https://github.com/R3gm/whisperX.git@cuda_12_x|' requirements_base.txt
# !uv run python -m pip install -q -r requirements_base.txt
# !uv run python -m pip install -q -r requirements_extra.txt
# !uv run python -m pip install -q onnxruntime-gpu==1.22.0

# !uv run python -m pip install -q openai==1.55.3 httpx==0.27.2 --force-reinstall --quiet

Install_PIPER_TTS = True # @param {type:"boolean"}

if Install_PIPER_TTS:
    # !uv run python -m pip install -q piper-tts==1.2.0

Install_Coqui_XTTS = True # @param {type:"boolean"}

if Install_Coqui_XTTS:
    # !uv run python -m pip install -q -r requirements_xtts.txt
    # !uv run python -m pip install -q TTS==0.21.1  --no-deps

# !sudo apt install -y libcudnn8 -q
# Out:
# /content
# Cloning into 'SoniTranslate'...
# remote: Enumerating objects: 1205, done.
# remote: Counting objects: 100% (571/571), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 1205 (delta 504), reused 438 (delta 432), pack-reused 634 (from 3)
# Receiving objects: 100% (1205/1205), 19.95 MiB | 19.96 MiB/s, done.
# Resolving deltas: 100% (832/832), done.
# /content/SoniTranslate
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 93.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.3 MB/s eta 0:00:00
# Reading package lists...
# Building dependency tree...
# Reading state information...
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Updated git hooks.
# Git LFS initialized.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 MB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 96.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 74.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 105.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 35.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 104.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 55.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 100.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 77.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 65.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 33.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.9/831.9 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 94.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.2/731.2 kB 51.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 563.4/563.4 kB 47.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 89.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 79.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.0/133.0 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 86.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 93.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.9/444.9 kB 39.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 59.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 34.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.5/828.5 kB 59.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 24.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.1/864.1 kB 58.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 60.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 93.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 38.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.7/260.7 kB 26.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 71.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.6/630.6 kB 53.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 111.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 87.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 kB 28.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 68.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 391.4/391.4 kB 37.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.9/789.9 kB 31.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.8/485.8 kB 40.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.9/222.9 kB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.6/241.6 kB 24.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.3/198.3 kB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.1/326.1 kB 30.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.3/407.3 kB 38.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 106.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 64.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 31.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 92.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 87.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 24.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 48.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 29.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.4/152.4 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 20.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 28.1 MB/s eta 0:00:00
# WARNING: typer 0.17.4 does not provide the extra 'all'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.1/384.1 kB 35.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 70.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.3/242.3 kB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 kB 42.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.4/247.4 kB 22.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 115.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 21.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 53.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.4/584.4 kB 46.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.2 MB/s eta 0:00:00
#   Building wheel for pyannote.audio (setup.py) ... done
#   Building wheel for whisperx (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
#   Building wheel for julius (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 67.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 20.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 86.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 94.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.9/374.9 kB 35.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.8/425.8 kB 32.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 63.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 25.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 21.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 103.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 41.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 111.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pyworld (pyproject.toml) ... done
#   Building wheel for fairseq (pyproject.toml) ... done
#   Building wheel for srt (setup.py) ... done
#   Building wheel for openvoice (pyproject.toml) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.2/283.2 MB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.7/348.7 kB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 64.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 73.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 25.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 78.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 62.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 100.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.5/31.5 MB 58.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 108.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 28.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 93.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 58.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 111.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 65.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 102.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 128.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 108.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.8/204.8 kB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.1/795.1 kB 57.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 112.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 MB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 80.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 85.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 34.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 34.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 35.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 6.7 MB/s eta 0:00:00
#   Building wheel for jieba (setup.py) ... done
#   Building wheel for bnnumerizer (setup.py) ... done
#   Building wheel for encodec (setup.py) ... done
#   Building wheel for gruut-ipa (setup.py) ... done
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Building wheel for gruut_lang_es (setup.py) ... done
#   Building wheel for gruut_lang_fr (setup.py) ... done
#   Building wheel for gruut (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 933.3/933.3 kB 6.3 MB/s eta 0:00:00
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   libcudnn8
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 444 MB of archives.
# After this operation, 1,099 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libcudnn8 8.9.7.29-1+cuda12.2 [444 MB]
# Fetched 444 MB in 4s (115 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libcudnn8.
# (Reading database ... 126374 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.9.7.29-1+cuda12.2_amd64.deb ...
# Unpacking libcudnn8 (8.9.7.29-1+cuda12.2) ...
# Setting up libcudnn8 (8.9.7.29-1+cuda12.2) ...

# %% [markdown]
# One important step is to accept the license agreement for using Pyannote. You need to have an account on Hugging Face and `accept the license to use the models`: https://huggingface.co/pyannote/speaker-diarization and https://huggingface.co/pyannote/segmentation
#
# Get your KEY TOKEN here: https://hf.co/settings/tokens
#
# When you are creating the new Access Token in Hugging Face, make sure to tick "Read access to contents of all public gated repos you can access".

# %%
#@markdown # `RUN THE WEB APP`
import os
import openai

from getpass import getpass
from openai import OpenAI

# 🔑 Ask for your API key securely (you type it, it won't be shown)
os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# Initialize the client
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])


YOUR_HF_TOKEN = "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" #@param {type:'string'}
# %env YOUR_HF_TOKEN={YOUR_HF_TOKEN}
theme = "Taithrah/Minimal" # @param ["Taithrah/Minimal", "aliabid94/new-theme", "gstaff/xkcd", "ParityError/LimeFace", "abidlabs/pakistan", "rottenlittlecreature/Moon_Goblin", "ysharma/llamas", "gradio/dracula_revamped"]
interface_language = "english" # @param ['arabic', 'azerbaijani', 'chinese_zh_cn', 'english', 'french', 'german', 'hindi', 'indonesian', 'italian', 'japanese', 'korean', 'marathi', 'polish', 'portuguese', 'russian', 'spanish', 'swedish', 'turkish', 'ukrainian', 'vietnamese']
verbosity_level = "info" # @param ["debug", "info", "warning", "error", "critical"]



# %cd /content/SoniTranslate
# !uv run python app_rvc.py --theme {theme} --verbosity_level {verbosity_level} --language {interface_language} --public_url
# Out:
# Enter your OpenAI API key: ··········
# env: YOUR_HF_TOKEN=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
# /content/SoniTranslate
# [INFO] >> PIPER TTS enabled
# [INFO] >> Coqui XTTS enabled
# [INFO] >> In this app, by using Coqui TTS (text-to-speech), you acknowledge and agree to the license.
# You confirm that you have read, understood, and agreed to the Terms and Conditions specified at the following link:
# https://coqui.ai/cpml.txt.
# [WARNING] >> The list of Edge TTS voices could not be obtained, switching to an alternative method
# [INFO] >> Working in: cpu
# Running on local URL:  http://127.0.0.1:7860
# IMPORTANT: You are using gradio version 4.19.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://7ecbfcaed8bcb956bf.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# [INFO] >> Content in 'outputs' removed.
# Traceback (most recent call last):
#   File "/content/SoniTranslate/.venv/lib/python3.10/site-packages/gradio/queueing.py", line 495, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/content/SoniTranslate/.venv/lib/python3.10/site-packages/gradio/route_utils.py", line 235, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/content/SoniTranslate/.venv/lib/python3.10/site-packages/gradio/blocks.py", line 1627, in process_api
#     result = await self.call_function(
#   File "/content/SoniTranslate/.venv/lib/python3.10/site-packages/gradio/blocks.py", line 1173, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/content/SoniTranslate/.venv/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/content/SoniTranslate/.venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2476, in run_sync_in_worker_thread
#     return await future
#   File "/content/SoniTranslate/.venv/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#   File "/content/SoniTranslate/.venv/lib/python3.10/site-packages/gradio/utils.py", line 690, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/SoniTranslate/app_rvc.py", line 365, in batch_multilingual_media_conversion
#     output_file = self.multilingual_media_conversion(
#   File "/content/SoniTranslate/app_rvc.py", line 556, in multilingual_media_conversion
#     raise Exception(
# Exception: To use an SRT file, you need to specify its original language (Source language)
# [INFO] >> Content in 'outputs' removed.
# [INFO] >> Cache flushed
# [INFO] >> Processing video...
# [INFO] >> Video codec: h264
# [INFO] >> Process video...
# [INFO] >> Process audio...
# [INFO] >> From SRT file...
# [INFO] >> Redivide text segments by: ['!', '?', '...', '。']
# [ERROR] >> 'chars'
# [INFO] >> Diarizing...
# [INFO] >> Translating...
# Translating: 100% 100/100 [00:14<00:00,  6.78it/s]
# [INFO] >> Text to speech...
# [INFO] >> Content in 'audio' removed.
# [INFO] >> EDGE TTS: ['SPEAKER_00']
#   0% 0/100 [00:00<?, ?it/s][INFO] >> September 15 >> audio/0.12.ogg
#   1% 1/100 [00:00<00:54,  1.80it/s][INFO] >> GPT announced the pre-sale configuration and price of its latest Wen 5 handheld game console >> audio/1.26.ogg
#   2% 2/100 [00:01<01:11,  1.37it/s][INFO] >> As the most powerful handheld game console that is about to be launched >> audio/4.899.ogg
#   3% 3/100 [00:02<01:09,  1.39it/s][INFO] >> The minimum version is 385 plus 32GB plus 1TB >> audio/7.519.ogg
#   4% 4/100 [00:02<01:09,  1.38it/s][INFO] >> Pre-sale price: 8699 yuan >> audio/11.218.ogg
#   5% 5/100 [00:03<01:07,  1.41it/s][INFO] >> The 395 plus 32GB plus 2TB version >> audio/13.08.ogg
#   6% 6/100 [00:04<01:09,  1.34it/s][INFO] >> It costs 9999 yuan >> audio/16.199.ogg
#   7% 7/100 [00:05<01:11,  1.30it/s][INFO] >> Up to 64G plus 4TB top configuration >> audio/18.0.ogg
#   8% 8/100 [00:05<01:10,  1.30it/s][INFO] >> Requires 12999 yuan >> audio/20.579.ogg
#   9% 9/100 [00:06<01:07,  1.36it/s][INFO] >> Batteries and a base are also available as an option >> audio/22.62.ogg
#  10% 10/100 [00:07<01:09,  1.29it/s][INFO] >> However, it should be noted that >> audio/24.859.ogg
#  11% 11/100 [00:08<01:03,  1.39it/s][INFO] >> GPD's standard configuration this time is >> audio/26.399.ogg
#  12% 12/100 [00:08<01:00,  1.46it/s][INFO] >> Machine body >> audio/28.14.ogg
#  13% 13/100 [00:09<00:55,  1.57it/s][INFO] >> External battery >> audio/29.239.ogg
#  14% 14/100 [00:09<00:51,  1.67it/s][INFO] >> And a dedicated connection cable between the battery and the host >> audio/30.0.ogg
#  15% 15/100 [00:10<00:53,  1.60it/s][INFO] >> And DC power adapter >> audio/32.159.ogg
#  16% 16/100 [00:10<00:51,  1.63it/s][INFO] >> Add DC power cable >> audio/34.179.ogg
#  17% 17/100 [00:11<00:50,  1.65it/s][INFO] >> The battery in the picture >> audio/35.299.ogg
#  18% 18/100 [00:12<00:48,  1.69it/s][INFO] >> Just when you need >> audio/36.399.ogg
#  19% 19/100 [00:12<00:45,  1.79it/s][INFO] >> In the case of the second battery >> audio/37.46.ogg
#  20% 20/100 [00:13<00:46,  1.72it/s][INFO] >> Available for purchase >> audio/38.899.ogg
#  21% 21/100 [00:13<00:47,  1.68it/s][INFO] >> So what do you think of this pricing? >> audio/39.619.ogg
#  22% 22/100 [00:14<00:45,  1.70it/s][INFO] >> The pre-sale time of GPD Q5 >> audio/41.88.ogg
#  23% 23/100 [00:15<00:45,  1.68it/s][INFO] >> It is scheduled for 10 am on September 25th. >> audio/43.939.ogg
#  24% 24/100 [00:15<00:47,  1.60it/s][INFO] >> Pre-sales will start on Tmall and JD.com >> audio/46.28.ogg
#  25% 25/100 [00:16<00:47,  1.56it/s][INFO] >> I will also share the pre-sale link as soon as possible. >> audio/48.579.ogg
#  26% 26/100 [00:17<00:46,  1.59it/s][INFO] >> Interested friends can pay attention to it >> audio/51.359.ogg
#  27% 27/100 [00:17<00:46,  1.58it/s][INFO] >> Then let’s summarize >> audio/53.219.ogg
#  28% 28/100 [00:18<00:42,  1.69it/s][INFO] >> Configuration information of this most powerful Win handheld >> audio/55.6.ogg
#  29% 29/100 [00:18<00:43,  1.64it/s][INFO] >> The machine adopts an external battery solution >> audio/57.859.ogg
#  30% 30/100 [00:19<00:45,  1.54it/s][INFO] >> Removed the GPD question number series >> audio/59.679.ogg
#  31% 31/100 [00:20<00:43,  1.57it/s][INFO] >> The keyboard design that has been used >> audio/61.859.ogg
#  32% 32/100 [00:20<00:43,  1.58it/s][INFO] >> Switch to an all-in-one handheld >> audio/63.259.ogg
#  33% 33/100 [00:21<00:41,  1.63it/s][INFO] >> The cooling system with built-in dual fans and four heat pipes >> audio/65.078.ogg
#  34% 34/100 [00:22<00:42,  1.55it/s][INFO] >> It can achieve a performance release of about 45-75W >> audio/68.578.ogg
#  35% 35/100 [00:22<00:42,  1.51it/s][INFO] >> In addition to the 395 processor >> audio/71.539.ogg
#  36% 36/100 [00:23<00:42,  1.51it/s][INFO] >> AIMax 385 nuclear option is also available >> audio/74.218.ogg
#  37% 37/100 [00:24<00:42,  1.47it/s][INFO] >> The latter's CPU specifications were cut in half to 8 cores. >> audio/76.578.ogg
#  38% 38/100 [00:24<00:41,  1.48it/s][INFO] >> But it retains the 32CU GPU >> audio/79.159.ogg
#  39% 39/100 [00:25<00:39,  1.53it/s][INFO] >> The loss of gaming performance is relatively small >> audio/81.718.ogg
#  40% 40/100 [00:26<00:38,  1.55it/s][INFO] >> It should be a more cost-effective choice >> audio/83.64.ogg
#  41% 41/100 [00:26<00:36,  1.61it/s][INFO] >> This time GPD Win5 >> audio/85.799.ogg
#  42% 42/100 [00:27<00:34,  1.67it/s][INFO] >> Equipped with a 7-inch native horizontal layer >> audio/87.299.ogg
#  43% 43/100 [00:27<00:34,  1.66it/s][INFO] >> Compared with the native touch screen, it will have a better experience >> audio/89.5.ogg
#  44% 44/100 [00:28<00:35,  1.58it/s][INFO] >> Lower latency >> audio/92.198.ogg
#  45% 45/100 [00:28<00:32,  1.69it/s][INFO] >> 16:9 ratio >> audio/93.399.ogg
#  46% 46/100 [00:29<00:31,  1.71it/s][INFO] >> Supports 1920×1080 resolution >> audio/94.599.ogg
#  47% 47/100 [00:30<00:31,  1.68it/s][INFO] >> 120Hz refresh rate >> audio/97.799.ogg
#  48% 48/100 [00:30<00:30,  1.70it/s][INFO] >> Time touch >> audio/99.299.ogg
#  49% 49/100 [00:31<00:28,  1.77it/s][INFO] >> Response time: about 6 horizontal >> audio/100.5.ogg
#  50% 50/100 [00:31<00:28,  1.72it/s][INFO] >> Color gamut coverage reaches 100% sRGB >> audio/102.198.ogg
#  51% 51/100 [00:32<00:30,  1.63it/s][INFO] >> In terms of storage >> audio/104.899.ogg
#  52% 52/100 [00:33<00:27,  1.73it/s][INFO] >> Available in 32GB, 64GB, and 128GB >> audio/106.239.ogg
#  53% 53/100 [00:33<00:32,  1.46it/s][INFO] >> Both are LPDDR5X8000 frequent memory >> audio/110.14.ogg
#  54% 54/100 [00:34<00:31,  1.45it/s][INFO] >> It also provides an M.2/2280PCIE4.0 SSD hard drive slot >> audio/113.239.ogg
#  55% 55/100 [00:35<00:34,  1.30it/s][INFO] >> Officially available 1TB, 2TB, and 4TB options >> audio/118.338.ogg
#  56% 56/100 [00:36<00:33,  1.30it/s][INFO] >> One SD3.0 ASI card reader >> audio/121.459.ogg
#  57% 57/100 [00:37<00:30,  1.39it/s][INFO] >> And also includes a compatible >> audio/123.959.ogg
#  58% 58/100 [00:37<00:28,  1.49it/s][INFO] >> Dedicated slot for mini SSD module >> audio/126.039.ogg
#  59% 59/100 [00:38<00:26,  1.52it/s][INFO] >> Can reach PCIE 4.0x1 >> audio/128.038.ogg
#  60% 60/100 [00:38<00:26,  1.53it/s][INFO] >> 1600Mbps sequential read and write speeds >> audio/130.658.ogg
#  61% 61/100 [00:39<00:27,  1.41it/s][INFO] >> GPD WAI 5 interface >> audio/133.5.ogg
#  62% 62/100 [00:40<00:25,  1.47it/s][INFO] >> There is a USB4 interface that supports power supply and video output >> audio/135.098.ogg
#  63% 63/100 [00:41<00:26,  1.40it/s][INFO] >> Bandwidth is 40G >> audio/138.318.ogg
#  64% 64/100 [00:41<00:24,  1.47it/s][INFO] >> A 5G C port with a burst speed of 1000ms >> audio/139.739.ogg
#  65% 65/100 [00:42<00:23,  1.47it/s][INFO] >> Support video output at the same time >> audio/142.818.ogg
#  66% 66/100 [00:42<00:21,  1.57it/s][INFO] >> And there is also a DC power interface that supports 180W power supply >> audio/144.5.ogg
#  67% 67/100 [00:43<00:22,  1.50it/s][INFO] >> This is probably the first time I've seen this on a handheld. >> audio/148.28.ogg
#  68% 68/100 [00:44<00:20,  1.53it/s][INFO] >> In addition, there is the mini4 card slot mentioned earlier. >> audio/150.938.ogg
#  69% 69/100 [00:44<00:20,  1.50it/s][INFO] >> And a 10G C port >> audio/154.06.ogg
#  70% 70/100 [00:45<00:18,  1.61it/s][INFO] >> and 3.5mm audio interface >> audio/156.299.ogg
#  71% 71/100 [00:46<00:18,  1.58it/s][INFO] >> This number of interfaces is considered luxury for a handheld device. >> audio/158.419.ogg
#  72% 72/100 [00:46<00:18,  1.51it/s][INFO] >> Finally, let me mention the rules for external batteries >> audio/161.519.ogg
#  73% 73/100 [00:47<00:18,  1.49it/s][INFO] >> This time the external battery has a capacity of 80 watt hours. >> audio/163.579.ogg
#  74% 74/100 [00:48<00:17,  1.51it/s][INFO] >> Can provide heavy load for about 2 hours >> audio/166.098.ogg
#  75% 75/100 [00:48<00:15,  1.57it/s][INFO] >> Severe 3-4 hours >> audio/168.098.ogg
#  76% 76/100 [00:49<00:15,  1.60it/s][INFO] >> Light 6 hours of battery life >> audio/170.098.ogg
#  77% 77/100 [00:49<00:14,  1.62it/s][INFO] >> The body dimensions are 267×111.6×24.21mm >> audio/172.098.ogg
#  78% 78/100 [00:50<00:15,  1.41it/s][INFO] >> The dimensions of the external battery are 110.76×110.3×18.1mm >> audio/176.098.ogg
#  79% 79/100 [00:51<00:16,  1.29it/s][INFO] >> The official did not give specific weight parameters >> audio/182.098.ogg
#  80% 80/100 [00:52<00:14,  1.36it/s][INFO] >> But there is news that the installed weight should be around 570 grams >> audio/184.098.ogg
#  81% 81/100 [00:53<00:14,  1.32it/s][INFO] >> Closer to the weight of the Switch 2 >> audio/187.258.ogg
#  82% 82/100 [00:53<00:12,  1.41it/s][INFO] >> External battery weights 340 grams >> audio/189.943.ogg
#  83% 83/100 [00:54<00:11,  1.47it/s][INFO] >> || The battery on the machine is about 910 grams >> audio/191.78.ogg
#  84% 84/100 [00:55<00:10,  1.51it/s][INFO] >> in addition >> audio/194.598.ogg
#  85% 85/100 [00:55<00:09,  1.65it/s][INFO] >> || The official new information says >> audio/195.098.ogg
#  86% 86/100 [00:56<00:08,  1.59it/s][INFO] >> 395 CPU part >> audio/196.9.ogg
#  87% 87/100 [00:56<00:07,  1.65it/s][INFO] >> || Gaming is an overkill >> audio/198.438.ogg
#  88% 88/100 [00:57<00:07,  1.67it/s][INFO] >> Even 385 can't run full >> audio/199.96.ogg
#  89% 89/100 [00:57<00:06,  1.67it/s][INFO] >> | Therefore, players who Pursue cost-effectiveness >> audio/201.758.ogg
#  90% 90/100 [00:58<00:06,  1.59it/s][INFO] >> You can't go wrong by choosing version 385 >> audio/203.8.ogg
#  91% 91/100 [00:59<00:05,  1.55it/s][INFO] >> And this time USB4 supports up to 100W charging power >> audio/206.06.ogg
#  92% 92/100 [01:00<00:05,  1.46it/s][INFO] >> | So there is no need to prepare higher standards >> audio/209.86.ogg
#  93% 93/100 [01:00<00:04,  1.51it/s][INFO] >> Desalination charging head >> audio/211.9.ogg
#  94% 94/100 [01:01<00:03,  1.63it/s][INFO] >> Even if you buy a 240W desalination >> audio/213.199.ogg
#  95% 95/100 [01:01<00:03,  1.64it/s][INFO] >> | It can only run at 100W power >> audio/215.658.ogg
#  96% 96/100 [01:02<00:02,  1.65it/s][INFO] >> | A complete waste of money >> audio/217.56.ogg
#  97% 97/100 [01:03<00:01,  1.69it/s][INFO] >> | It can be seen that GPT officials still take good care of players. >> audio/218.699.ogg
#  98% 98/100 [01:03<00:01,  1.56it/s][INFO] >> So that’s all the information summarized >> audio/221.36.ogg
#  99% 99/100 [01:04<00:00,  1.60it/s][INFO] >> Finally, I hope to ask for a three-repost and follow >> audio/223.5.ogg
# 100% 100/100 [01:05<00:00,  1.54it/s]
# [INFO] >> Apply acceleration
# [INFO] >> Content in 'audio2/audio/' removed.
# 100it [00:09, 10.33it/s]
# [INFO] >> Creating final translated video...
# 100it [00:16,  5.98it/s]
# [INFO] >> Burn subtitles
# [INFO] >> Done: /content/SoniTranslate/outputs/32419086344-1-192__en.mp4
# [INFO] >> Content in 'outputs' removed.
# [INFO] >> Apply acceleration
# [INFO] >> Content in 'audio2/audio/' removed.
# 100it [00:10,  9.29it/s]
# [INFO] >> Creating final translated video...
# 100it [00:24,  4.15it/s]
# [INFO] >> Voiceless Track Separation...
# 100% 39/39 [05:25<00:00,  8.34s/it]
# [INFO] >> Done: /content/SoniTranslate/outputs/32419086344-1-192__en.mp4
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://7ecbfcaed8bcb956bf.gradio.live

# %% [markdown]
# Open the `public URL` when it appears
